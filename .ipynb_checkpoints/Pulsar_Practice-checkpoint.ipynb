# %% [markdown]
# # Introduction
#
# A <b>Neutron Star</b> is a star that forms when a giant star burns all of its Hydrogen into heavier elements, thus no longer emitting enough energy to maintain its structure, so it collapses under its own weight: All of its electrons collapse into the nucleus. A <b>Pulsar</b> is a neutron Star that spins rapidly, containing a beam of electromagnetic radiation along its magnetic poles, which when swept across Earth is detectable. Pulsars are important for many reasons, a few of them being:
# <ul>
#     <li>Confirming The General Theory of Relativety</li>
#     <li>Allowing for new insights in Nuclear Physics</li>
#     <li>Confirmation of Gravity Waves(2017)</li>
#     <li>Providing evidence on the origin of heavy metals</li>
# </ul>

# %% [markdown]
# ## Import Statements

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sqlite3 

conn = sqlite3.connect('pulsar_data.db')    #Create SQL Database named 'pulsar_data'
pulsar_data = pd.read_csv('pulsar_stars.csv')    #Read the CSV file
pulsar_data.to_sql('pulsar_data', conn, if_exists = 'replace')    #Populate the database with the CSV entries

# %% [markdown]
# ## Data Inspection

# %%
top_of = list(pulsar_data)
print('The names of the columns are: \t')
count = 1
for top in top_of:
    print('\n {}. {}'.format(count, top))
    count += 1
# Out:
# The names of the columns are:
#
#  1. mean_of_the_integrated_profile
#
#  2. standard_deviation_of_the_integrated_profile
#
#  3. excess_kurtosis_of_the_integrated_profile
#
#  4. skewness_of_the_integrated_profile
#
#  5. mean_of_the_dm_snr_curve
#
#  6. standard_deviation_of_the_dm_snr_curve
#
#  7. excess_kurtosis_of_the_dm_snr_curve
#
#  8. skewness_of_the_dm_snr_curve
#
#  9. target_class

# %% [markdown]
# <i>The dataset has 9 columns, with the above names for each column. The number of rows corresponds to how many potential Pulsars are in this study, and to see how many potential Pulsars there may be, the following statement is executed:</i>

# %%
rows = len(pulsar_data)
print("There are {} rows, and therefore there are that many potential Pulsars".format(rows))
# Out:
# There are 17898 rows, and therefore there are that many potential Pulsars

# %% [markdown]
# Out of the thousands of rows, how does one know which of these entries are Pulsars and which ones are radio interference and noise? This is found in the <b>target_class</b> column. The identifiers are 1 & 0; 1 is a Pulsar and 0 is something else. To see the rows with a 1, run the code:

# %%
not_interference = pulsar_data[pulsar_data['target_class'] > 0] #Sets the index to all entries where target_class > 1 = True
not_interference.head()    #Display just the first five entries
# Out:
#     mean_of_the_integrated_profile  \
# 19                       99.367188
# 42                      120.554688
# 61                       27.765625
# 92                       23.625000
# 93                       94.585938
#
#     standard_deviation_of_the_integrated_profile  \
# 19                                     41.572202
# 42                                     45.549905
# 61                                     28.666042
# 92                                     29.948654
# 93                                     35.779823
#
#     excess_kurtosis_of_the_integrated_profile  \
# 19                                   1.547197
# 42                                   0.282924
# 61                                   5.770087
# 92                                   5.688038
# 93                                   1.187309
#
#     skewness_of_the_integrated_profile  mean_of_the_dm_snr_curve  \
# 19                            4.154106                 27.555184
# ...

# %% [markdown]
# According to the dataset documentation, there are 1639 'positive examples' (Pulsars); let's confirm that this is true:

# %%
print(len(not_interference))
# Out:
# 1639

# %% [markdown]
# ## Mean of the Integrated Profile

# %% [markdown]
# The <b>Integrated Profile</b> (IP) of a Pulsar is akin to the Pulsar's fingerprint. This is the frequency at which the Pulsar 'pulses' EM waves; the frequencies may vary considerably from one event to the next, but on average the integrated profile is quite stable.

# %% [markdown]
# Let's take a look at the spread (range) of the values for the fingerprints of Pulsars and for random noise:

# %%
##Make a list of all of the Pulsar integrated profiles using the 'not_interference' array
spread_of_stars = []
i = 0
for star in range(0, len(not_interference)-1):
    spread_of_stars.append(not_interference.iloc[i][0])
    i += 1


##Retrieve the minimum and maximum values of the integrated profiles of noise using SQL query
spread_of_noise = pd.read_sql_query("""
SELECT MIN(mean_of_the_integrated_profile), 
MAX(mean_of_the_integrated_profile)
FROM pulsar_data
WHERE target_class = 0;
""", conn)

# %% [markdown]
# Below is a plot of the range of the Integrated Profiles of <i>Pulsars</i>:

# %%
plt.boxplot(spread_of_stars)
plt.title('Spread of Integrated Profile of Pulsars')
plt.xticks([1], ['Pulsars'])
plt.ylabel('Integrated Profile');

# %% [markdown]
# As can be seen from the boxplot above, the range of the Pulsar profiles goes from a value around 5, up to about 140; however, the majority of the profiles are contained from 30 to about 80. Let's take a look at the range of the profiles from the noise:

# %%
plt.boxplot(spread_of_noise)  ##obtained with SQL query
plt.title('Spread of Integrated Profile of Noise')
plt.xticks([1], ['Noise'])
plt.ylabel('Integrated Profile');

# %% [markdown]
# The range of values of the Profiles for the noise is understandably larger, as there are more samples; however, the bulk of the values are contained in the range from about 65 to 150, with the average value being about double what it was for the average value of actual Pulsars!

# %% [markdown]
# Knowing Pulsars have a unique Integrated Profile, it suffices to say that the count of distinct Integrated Profiles should be 1639; let's investigate using the following SQL query:

# %%
pd.read_sql_query("""
SELECT COUNT(DISTINCT mean_of_the_integrated_profile)
AS 'Unique Integrated Profiles'
FROM pulsar_data
WHERE target_class = 1;
""", conn)
# Out:
#    Unique Integrated Profiles
# 0                        1544

# %% [markdown]
# Evidently, 95 of the positive examples do not have a unique Integrated Profile. This means that the integrated profile isn't the only determining factor for the classification of a Pulsar!

# %% [markdown]
# ## Visualization of Data

# %% [markdown]
# A Correlation Heat Map can help to visualize the relationships columns have with one another. This is done using seaborn:

# %%
correlated_data = pulsar_data.corr()  ##The .corr() method creates an array of correlations between the columns
plt.figure(figsize=(10,8))
sns.heatmap(correlated_data,annot=True,
            cmap='coolwarm',
            linewidth=2)              ##annot=True means the actual correlation value will be given in each square
plt.title("CORRELATION BETWEEN VARIABLES")
plt.show()

# %% [markdown]
# A high correlation is seen in the following pairs of columns:
# <ul>
#     <li>excess kurtosis of the integrated profile & mean of the integrated profile</li>
#     <li>skewness of the integrated profile & excess kurtosis of the integrated profile</li>
#     <li>skewness of the dm-snr curve & excess kurtosis of the dm-snr curve</li>
# </ul>
#
# This is not surprising, since these are all statistical terms

# %% [markdown]
# Next, a histogram for each feature(of confirmed Pulsars) allows for visualization of the quanitity of a feature:

# %%
not_interference.hist(bins = 10, figsize=(20,15), edgecolor='black');

# %% [markdown]
# A couple of observations can be made from the histograms of <b>Pulsar</b> data:
# <ul>
#     <li>The skewness of the integrated profile is positive</li>
#     <li>The standard deviation of the integrated profile is mostly between 30 and 40</li>
#     <li>The mean of the integrated profile is mostly between 20 and 80 (confirming above observation of boxplot), with most of the values being around 40.</li>
# </ul>

# %% [markdown]
# A scatter graph, to see what a typical high correlation looks like:

# %%
x = pd.read_sql_query("""
SELECT excess_kurtosis_of_the_integrated_profile
FROM pulsar_data
WHERE target_class = 1;
""", conn)

y = pd.read_sql_query("""
SELECT skewness_of_the_integrated_profile
FROM pulsar_data
WHERE target_class = 1;
""", conn)
plt.figure(figsize = (10, 10))
plt.xlabel('Mean Profile')
plt.ylabel('Standard Deviation of Mean Profile')
plt.scatter(x,y,);

# %%
X = pd.read_sql_query("""
SELECT mean_of_the_integrated_profile
FROM pulsar_data
WHERE target_class = 1;
""", conn)

Y = pd.read_sql_query("""
SELECT mean_of_the_dm_snr_curve
FROM pulsar_data
WHERE target_class = 1;
""", conn)

plt.figure(figsize=(10,8))
plt.ylabel('Mean of the dm-snr Curve')
plt.xlabel('Mean of the Integrated Profile')
plt.scatter(X, Y);

# %% [markdown]
# From the scatter plot it can be observed that there is an exponential decay between the integrated profile and the mean on the dm-snr curve: As the integrated profile increases, the mean of the dm-snr curve decreases exponentially, other than the outliers.

# %% [markdown]
# ## Analysis:

# %% [markdown]
# After plotting visuals and running SQL queries, some conclusions can be made. First, strictly speaking, the value of the Integrated Profile is not the sole determiner of what can be classified as a Pulsar, since the quantity of unique values is less than the quantity of confirmed Pulsars. Second, most of the Integrated Profiles are around 40 (corresponding to 400MHz): from the research I have done, this is the frequency at which Pulsars emmit their largest intensity. Another observation is the exponential decay discussed with mean of the dn-snr curve VS mean of the integrated profile.
